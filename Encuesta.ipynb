# %% [markdown]
# <a href="https://colab.research.google.com/github/MauriLoria/Python/blob/main/Encuesta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/Encuesta_Respuestas.txt", sep='\t',encoding='latin-1')
df.head()
# Out:
#                Tiempo  Edad Genero                                    Redes  \
# 0   7/11/2025 9:01:05    50  Varon                       Whatsapp, Facebook
# 1  7/11/2025 10:25:24    19  Varon                      Whatsapp, Instagram
# 2  7/11/2025 14:08:10    19  Mujer                      Whatsapp, Instagram
# 3   7/12/2025 9:23:22    47  Mujer                      Whatsapp, Instagram
# 4  7/12/2025 10:35:41    72  Mujer  Whatsapp, Facebook, Instagram, Telegram
#
#                Uso        Horario
# 0          Trabajo           Otro
# 1          Trabajo  Por la mañana
# 2  Entretenimiento   Por la tarde
# 3          Trabajo  Por la mañana
# 4          Trabajo   Por la tarde

# %%
df['Redes'][1]
# Out:
# 'Whatsapp, Instagram'

# %%
facebook = df.copy
facebook = facebook('Redes == "Facebook"' and 'Edad<=18')
print(facebook)
filtrado = facebook.str.split(",")
print(filtrado[0][1])
#print(genero_redes)
# Out:
#                 Tiempo  Edad Genero                                    Redes  \
# 0    7/11/2025 9:01:05    50  Varon                       Whatsapp, Facebook
# 1   7/11/2025 10:25:24    19  Varon                      Whatsapp, Instagram
# 2   7/11/2025 14:08:10    19  Mujer                      Whatsapp, Instagram
# 3    7/12/2025 9:23:22    47  Mujer                      Whatsapp, Instagram
# 4   7/12/2025 10:35:41    72  Mujer  Whatsapp, Facebook, Instagram, Telegram
# ..                 ...   ...    ...                                      ...
# 80  9/14/2025 12:14:09    27  Mujer                      Whatsapp, Instagram
# 81  9/14/2025 12:21:19    22  Mujer                          Instagram, Otro
# 82  9/14/2025 15:14:20    28  Mujer                                  Tik Tok
# 83  9/14/2025 23:57:12    16  Varon                      Whatsapp, Instagram
# 84  9/15/2025 23:17:14    29  Varon                      Whatsapp, Instagram
#
#                 Uso        Horario
# 0           Trabajo           Otro
# 1           Trabajo  Por la mañana
# 2   Entretenimiento   Por la tarde
# 3           Trabajo  Por la mañana
# 4           Trabajo   Por la tarde
# ..              ...            ...
# 80  Entretenimiento   Por la noche
# 81  Entretenimiento           Otro
# 82  Entretenimiento   Por la noche
# 83  Entretenimiento   Por la tarde
# 84             Otro   Por la tarde
#
# [85 rows x 6 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1442461257.py in <cell line: 0>()
#       2 facebook = facebook('Redes == "Facebook"' and 'Edad<=18')
#       3 print(facebook)
# ----> 4 filtrado = facebook.str.split(",")
#       5 print(filtrado[0][1])
#       6 #print(genero_redes)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
display(df.head())
# Out:
#                Tiempo  Edad Genero                                    Redes  \
# 0   7/11/2025 9:01:05    50  Varon                       Whatsapp, Facebook
# 1  7/11/2025 10:25:24    19  Varon                      Whatsapp, Instagram
# 2  7/11/2025 14:08:10    19  Mujer                      Whatsapp, Instagram
# 3   7/12/2025 9:23:22    47  Mujer                      Whatsapp, Instagram
# 4  7/12/2025 10:35:41    72  Mujer  Whatsapp, Facebook, Instagram, Telegram
#
#                Uso        Horario
# 0          Trabajo           Otro
# 1          Trabajo  Por la mañana
# 2  Entretenimiento   Por la tarde
# 3          Trabajo  Por la mañana
# 4          Trabajo   Por la tarde

# %%
filtro_fecha = df.Edad <= 18
print(df.loc[filtro_fecha, ('Edad', 'Redes')])
# Out:
#     Edad                               Redes
# 5     15        Whatsapp, Instagram, Tik Tok
# 9     17                  Instagram, Tik Tok
# 12    16                 Whatsapp, Instagram
# 14    16                  Instagram, Tik Tok
# 20    16        Whatsapp, Instagram, Tik Tok
# 22    15                            Whatsapp
# 23    16                           Instagram
# 24    16                  Instagram, Tik Tok
# 26    15  Whatsapp, Instagram, Tik Tok, Otro
# 31    16  Whatsapp, Instagram, Tik Tok, Otro
# 37    16        Whatsapp, Instagram, Tik Tok
# 40    16        Whatsapp, Instagram, Tik Tok
# 46    15                            Whatsapp
# 48    16        Whatsapp, Instagram, Tik Tok
# 49    16  Whatsapp, Instagram, Tik Tok, Otro
# 53    16                            Whatsapp
# 68    17                             Tik Tok
# 71    18                  Instagram, Tik Tok
# 74    17                             Tik Tok
# 83    16                 Whatsapp, Instagram
