# %% [markdown]
# <a href="https://colab.research.google.com/github/MauriLoria/Python/blob/main/Encuesta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
ruta = "/content/Encuesta.txt"   ### Ubicación de la base de datos
#df = pd.read_csv(ruta, sep='\t',encoding='latin-1')
df = pd.read_csv(ruta, sep='\t')
df.head()
# Out:
#        Marca temporal  Edad Genero                                    Redes  \
# 0   11/7/2025 9:01:05    50  Varon                       Whatsapp, Facebook
# 1  11/7/2025 10:25:24    19  Varon                      Whatsapp, Instagram
# 2  11/7/2025 14:08:10    19  Mujer                      Whatsapp, Instagram
# 3   12/7/2025 9:23:22    47  Mujer                      Whatsapp, Instagram
# 4  12/7/2025 10:35:41    72  Mujer  Whatsapp, Facebook, Instagram, Telegram
#
#                Uso        Horario
# 0          Trabajo           Otro
# 1          Trabajo  Por la mañana
# 2  Entretenimiento   Por la tarde
# 3          Trabajo  Por la mañana
# 4          Trabajo   Por la tarde

# %%
redes_sociales = df.copy()
redes_sociales['Redes'] = redes_sociales['Redes'].str.split(",")

# %%
print(redes_sociales.head())
redes_sociales.info()
# Out:
#        Marca temporal  Edad Genero  \
# 0   11/7/2025 9:01:05    50  Varon
# 1  11/7/2025 10:25:24    19  Varon
# 2  11/7/2025 14:08:10    19  Mujer
# 3   12/7/2025 9:23:22    47  Mujer
# 4  12/7/2025 10:35:41    72  Mujer
#
#                                           Redes              Uso  \
# 0                         [Whatsapp,  Facebook]          Trabajo
# 1                        [Whatsapp,  Instagram]          Trabajo
# 2                        [Whatsapp,  Instagram]  Entretenimiento
# 3                        [Whatsapp,  Instagram]          Trabajo
# 4  [Whatsapp,  Facebook,  Instagram,  Telegram]          Trabajo
#
#          Horario
# 0           Otro
# 1  Por la mañana
# 2   Por la tarde
# 3  Por la mañana
# 4   Por la tarde
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Marca temporal  94 non-null     object
# ...

# %%
edad1 = redes_sociales[(redes_sociales["Edad"]<=18)].copy()
edad2 = redes_sociales[(redes_sociales["Edad"]>18) & (redes_sociales['Edad']<=30)].copy()
edad3 = redes_sociales[(redes_sociales["Edad"]>30) & (redes_sociales['Edad']<=40)].copy()
edad4 = redes_sociales[(redes_sociales["Edad"]>40)].copy()
instagram_edad1 = edad1[edad1['Redes'].apply(lambda x: any("Instagram" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
whatsapp_edad1 = edad1[edad1['Redes'].apply(lambda x: any("Whatsapp" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
facebook_edad1 = edad1[edad1['Redes'].apply(lambda x: any("Facebook" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
tiktok_edad1 = edad1[edad1['Redes'].apply(lambda x: any("Tik Tok" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
telegram_edad1 = edad1[edad1['Redes'].apply(lambda x: any("Telegram" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
otro_edad1 = edad1[edad1['Redes'].apply(lambda x: any("Otro" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
instagram_edad2 = edad2[edad2['Redes'].apply(lambda x: any("Instagram" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
whatsapp_edad2 = edad2[edad2['Redes'].apply(lambda x: any("Whatsapp" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
facebook_edad2 = edad2[edad2['Redes'].apply(lambda x: any("Facebook" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
tiktok_edad2 = edad2[edad2['Redes'].apply(lambda x: any("Tik Tok" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
telegram_edad2 = edad2[edad2['Redes'].apply(lambda x: any("Telegram" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
otro_edad2 = edad2[edad2['Redes'].apply(lambda x: any("Otro" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
instagram_edad3 = edad3[edad3['Redes'].apply(lambda x: any("Instagram" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
whatsapp_edad3 = edad3[edad3['Redes'].apply(lambda x: any("Whatsapp" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
facebook_edad3 = edad3[edad3['Redes'].apply(lambda x: any("Facebook" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
tiktok_edad3 = edad3[edad3['Redes'].apply(lambda x: any("Tik Tok" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
telegram_edad3 = edad3[edad3['Redes'].apply(lambda x: any("Telegram" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
otro_edad3 = edad3[edad3['Redes'].apply(lambda x: any("Otro" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
instagram_edad4 = edad4[edad4['Redes'].apply(lambda x: any("Instagram" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
whatsapp_edad4 = edad4[edad4['Redes'].apply(lambda x: any("Whatsapp" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
facebook_edad4 = edad4[edad4['Redes'].apply(lambda x: any("Facebook" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
tiktok_edad4 = edad4[edad4['Redes'].apply(lambda x: any("Tik Tok" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
telegram_edad4 = edad4[edad4['Redes'].apply(lambda x: any("Telegram" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
otro_edad4 = edad4[edad4['Redes'].apply(lambda x: any("Otro" in item.strip() for item in x))]   ### strip() elimina espacio/s en blanco.
#print("La Cantidad de mayores de 18 años que usan Instagram son: ", instagram_edad3.Redes.count())
#print("La Cantidad de mayores de 18 años que usan Whatsapp son: ", whatsapp_edad3.Redes.count())
#print("La Cantidad de mayores de 18 años que usan Facebook son: ", facebook_edad3.Redes.count())
#print("La Cantidad de mayores de 18 años que usan Tik Tok son: ", tiktok_edad3.Redes.count())
#print("La Cantidad de mayores de 18 años que usan Tik Tok son: ", telegram_edad3.Redes.count())
#print("La Cantidad de mayores de 18 años que usan otras Redes Sociales son: ", otro_edad3.Redes.count())
redes = ["Instagram", "Whatsapp", "Facebook", "Tik Tok", "Telegram", "Otra"]
cantidad_edad1 = [instagram_edad1.Redes.count(), whatsapp_edad1.Redes.count(), facebook_edad1.Redes.count(), tiktok_edad1.Redes.count(), telegram_edad1.Redes.count(), otro_edad1.Redes.count()]
cantidad_edad2 = [instagram_edad2.Redes.count(), whatsapp_edad2.Redes.count(), facebook_edad2.Redes.count(), tiktok_edad2.Redes.count(), telegram_edad2.Redes.count(), otro_edad2.Redes.count()]
cantidad_edad3 = [instagram_edad3.Redes.count(), whatsapp_edad3.Redes.count(), facebook_edad3.Redes.count(), tiktok_edad3.Redes.count(), telegram_edad3.Redes.count(), otro_edad3.Redes.count()]
cantidad_edad4 = [instagram_edad4.Redes.count(), whatsapp_edad4.Redes.count(), facebook_edad4.Redes.count(), tiktok_edad4.Redes.count(), telegram_edad4.Redes.count(), otro_edad4.Redes.count()]

# %%
plt.figure(figsize=(12,5))

plt.subplot(121)
plt.title("Menores de 18 años en las Redes Sociales")
barras=plt.bar(redes, cantidad_edad1)
plt.bar_label(barras)
plt.xlabel("Redes Sociales (Figura N° 1)")
plt.ylabel("Cantidad")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()


plt.subplot(122)
plt.title('Mayores de 18 y menores de 31 años en las Redes Sociales')
barras=plt.bar(redes, cantidad_edad2)
plt.bar_label(barras)
plt.xlabel("Redes Sociales (Figura N° 2)")
plt.ylabel("Cantidad")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()


plt.show()

plt.figure(figsize=(12,5))

plt.subplot(121)
plt.title('Mayores de 30 y menores de 41 años y las Redes Sociales')
barras=plt.bar(redes, cantidad_edad3)
plt.bar_label(barras)
plt.xlabel("Redes Sociales (Figura N° 3)")
plt.ylabel("Cantidad")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()


plt.subplot(122)
plt.title('Mayores de 40 años y las Redes Sociales')
barras=plt.bar(redes, cantidad_edad4)
plt.bar_label(barras)
plt.xlabel("Redes Sociales (Figura N° 4)")
plt.ylabel("Cantidad")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()


plt.show()

# %% [markdown]
# En la Figura Nº 1 y N° 2 queda demostrado que los más jovenes, hasta los 30 años, no usan Facebook o pocos lo hacen.
#
# Tambien queda demostrado en la Figura N° 1, que los mas chicos (menores de 18 años) usan casi en la misma proporcion Instagram y Tik Tok.
# En el rango de edad siguiente también comienzan a usar Tik Tok pero no en la misma proporción que Instagram (Figura N° 2) y Observamos el uso de Telegram (Figura N° 2)

# %% [markdown]
# Analizando la Figura N° 3 y la Figura N° 4 no podemos afirmar la hipotesis planteada en la encuesta, ya que en ambas figuras queda demostrado que usan también Instagram aún mas que Facebook. Solo podemos destacar que usan poco Tik Tok con respecto a los más jovenes (Figura N° 1 y N° 2)
# También se refleja el uso de Telegram en ambas categorias de edad (Figura N° 3 y N° 4)

# %%
plt.figure(figsize=(12,5))

plt.subplot(121)
plt.pie(cantidad_edad1, labels=redes, autopct='%1.1f%%', startangle=90) ### autopct muestra los porcentajes en el grafico y stantangle el angulo de inicio
plt.title('Menores de 19 años y las Redes Sociales')
plt.axis('equal')

plt.subplot(122)
plt.pie(cantidad_edad2, labels=redes, autopct='%1.1f%%', startangle=90) ### autopct muestra los porcentajes en el grafico y stantangle el angulo de inicio
plt.title('Mayores de 18 y menores de 31 años y las Redes Sociales')
plt.axis('equal')

plt.show()

plt.figure(figsize=(12,5))

plt.subplot(121)
plt.pie(cantidad_edad3, labels=redes, autopct='%1.1f%%', startangle=90) ### autopct muestra los porcentajes en el grafico y stantangle el angulo de inicio
plt.title('Mayores de 30 y menores de 41 años y las Redes Sociales')
plt.axis('equal')

plt.subplot(122)
plt.pie(cantidad_edad4, labels=redes, autopct='%1.1f%%', startangle=90) ### autopct muestra los porcentajes en el grafico y stantangle el angulo de inicio
plt.title('Mayores de 40 años y las Redes Sociales')
plt.axis('equal')   ### equal establece la misma escala en ambos ejes

plt.show()

# %%
genero_mujer = redes_sociales[(redes_sociales["Genero"] == "Mujer")].copy()
genero_varon = redes_sociales[(redes_sociales["Genero"] == "Varon")].copy()
genero = genero_mujer.merge(genero_varon, how='outer', on='Genero').value_counts('Genero')
print(genero)
#print(genero_mujer.head(), genero_varon.head())
# Out:
# Genero
# Mujer    61
# Varon    33
# Name: count, dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(12,5))

plt.subplot(121)

redes_sociales_redes = redes_sociales.explode('Redes')  ### La funcion explode lo hace iterable

redes_sociales_redes['Redes'] = redes_sociales_redes['Redes'].str.strip() ### strip() elimina espacio/s en blanco.

g = sns.countplot(data=redes_sociales_redes, x='Redes', hue='Genero')
for container in g.containers:
    g.bar_label(container)    ### Indica la cantidad en la cima de la barra
plt.title("Redes Sociales por Género")
plt.xlabel("Redes Sociales")
plt.ylabel("Cantidad de Usuarios")
plt.xticks(rotation=45, ha='right') ### Especifica la inclinacion de las etiquetas del eje x
plt.tight_layout()    ### Ajusta el espaciado entre los subplot

plt.subplot(122)
plt.pie(genero, labels=genero.index, autopct='%1.1f%%', startangle=90) ### autopct muestra los porcentajes en el grafico y stantangle el angulo de inicio
plt.title('Géneros')
plt.axis('equal')

plt.show()

# %%
orden_uso = ['Por la mañana', 'Por la tarde', 'Por la noche', 'Otro']
plt.figure(figsize=(12,5))

plt.subplot(121)
g = sns.countplot(data=genero_mujer, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Redes Sociales Usadas por Mujeres")
plt.xlabel("Redes Sociales")
plt.ylabel("Cantidad de Usuarios")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(122)
g = sns.countplot(data=genero_varon, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Redes Sociales Usadas por Hombres")
plt.xlabel("Redes Sociales")
plt.ylabel("Cantidad de Usuarios")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
orden_uso = ['Por la mañana', 'Por la tarde', 'Por la noche', 'Otro']
plt.figure(figsize=(12,5))

plt.subplot(141)
g = sns.countplot(data=instagram_edad1, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Instagram hasta 18 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(142)
g = sns.countplot(data=instagram_edad2, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Instagram de 19 a 30 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(143)
g = sns.countplot(data=instagram_edad3, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Instagram de 31 a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(144)
g = sns.countplot(data=instagram_edad4, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Instagram mayores a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

plt.figure(figsize=(12,5))

plt.subplot(141)
g = sns.countplot(data=whatsapp_edad1, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Whatsapp hasta 18 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(142)
g = sns.countplot(data=whatsapp_edad2, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Whatsapp de 19 a 30 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(143)
g = sns.countplot(data=whatsapp_edad3, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Whatsapp de 31 a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(144)
g = sns.countplot(data=whatsapp_edad4, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Whatsapp mayores a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

plt.figure(figsize=(12,5))

plt.subplot(141)
g = sns.countplot(data=facebook_edad1, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Facebook hasta 18 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(142)
g = sns.countplot(data=facebook_edad2, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Facebook de 19 a 30 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(143)
g = sns.countplot(data=facebook_edad3, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Facebook de 31 a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(144)
g = sns.countplot(data=facebook_edad4, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Facebook mayores a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

plt.figure(figsize=(12,5))

plt.subplot(141)
g = sns.countplot(data=tiktok_edad1, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Tik Tok hasta 18 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(142)
g = sns.countplot(data=tiktok_edad2, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Tik Tok de 19 a 30 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(143)
g = sns.countplot(data=tiktok_edad3, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Tik Tok de 31 a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(144)
g = sns.countplot(data=tiktok_edad4, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Tik Tok mayores a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

plt.figure(figsize=(12,5))

plt.subplot(141)
g = sns.countplot(data=telegram_edad1, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Telegram hasta 18 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(142)
g = sns.countplot(data=telegram_edad2, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Telegram de 19 a 30 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(143)
g = sns.countplot(data=telegram_edad3, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Telegram de 31 a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(144)
g = sns.countplot(data=telegram_edad4, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Telegram mayores a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

plt.figure(figsize=(12,5))

plt.subplot(141)
g = sns.countplot(data=otro_edad1, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Otras Redes hasta 18 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(142)
g = sns.countplot(data=otro_edad2, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Otras Redes de 19 a 30 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(143)
g = sns.countplot(data=otro_edad3, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Otras Redes de 31 a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.subplot(144)
g = sns.countplot(data=otro_edad4, x='Horario', hue='Uso', order=orden_uso)
for container in g.containers:
    g.bar_label(container)
plt.title("Otras Redes mayores a 40 años")
plt.xlabel("Horarios")
plt.ylabel("Usos")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %% [markdown]
# Este ultimo analis podra dirigirnos al segmento que se esta buscando, en el horario, edad y especialmente en que redes sociales, para lograr mas efeciencia a la hora de planificar la publicidad.
